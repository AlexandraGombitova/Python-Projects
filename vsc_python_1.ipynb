# %% [markdown]
# # 🐍 VSC Python I.

# %% [markdown]
# ## 🎶💬 I. TTS

# %%
# %pip install pyttsx3
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyttsx3


engine = pyttsx3.init()
rate = engine.getProperty("rate")
voices = engine.getProperty("voices")

print("Speed -->", rate)

engine.setProperty("voice", voices[0].id)
engine.setProperty("rate", 300)
engine.say("Hello World")
engine.runAndWait()

# %% [markdown]
# ## II. Seaborn

# %%
import seaborn as sns

flowers = sns.load_dataset("iris")
sns.lineplot(x = "sepal_length", y = "sepal_width", data = flowers)
sns.set_style("dark")

# %%
import seaborn as sns


sns.set_theme()
tips = sns.load_dataset("tips")

sns.relplot(data = tips, x = "total_bill", y = "tip" , col = "time", hue = "smoker", style = "smoker")

# %%
import seaborn as sns
import matplotlib as plt

palette_of_colors = sns.color_palette("Greens")
sns.palplot(palette_of_colors)
